# %%
import pandas as pd

# %% [markdown]
# LOAD THE DATASET

# %%
cd=pd.read_csv('/content/cleaned_cholesterol.csv')

# %% [markdown]
# UNDERSTAND CHOLESTEROL DATASET AND ITS FEATURE

# %%
#Display first few rows
cd.head()
# Out:
#    age  sex  cp  trestbps  fbs  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   1       145    1        2      150      0      2.3      3   0
# 1   67    1   4       160    0        2      108      1      1.5      2   3
# 2   67    1   4       120    0        2      129      1      2.6      2   2
# 3   37    1   3       130    0        0      187      0      3.5      3   0
# 4   41    0   2       130    0        2      172      0      1.4      1   0
#
#    thal  num  chol
# 0     6    0   233
# 1     3    2   286
# 2     7    1   229
# 3     3    0   250
# 4     3    0   204

# %%
#shape of cholesterol dataset
cd.shape
# Out:
# (303, 14)

# %% [markdown]
# It has 303 rows and 14 columns

# %%
#Structure and basic info of cholesterol dataset
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   fbs       303 non-null    int64
#  5   restecg   303 non-null    int64
#  6   thalach   303 non-null    int64
#  7   exang     303 non-null    int64
#  8   oldpeak   303 non-null    float64
#  9   slope     303 non-null    int64
#  10  ca        303 non-null    int64
#  11  thal      303 non-null    int64
#  12  num       303 non-null    int64
#  13  chol      303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Summary statistics of cholesterol dataset
cd.describe()
# Out:
#               age         sex          cp    trestbps         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769    0.148515    0.990099
# std      9.038662    0.467299    0.960126   17.599748    0.356198    0.994971
# min     29.000000    0.000000    1.000000   94.000000    0.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000    0.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000    0.000000    1.000000
# 75%     61.000000    1.000000    4.000000  140.000000    0.000000    2.000000
# max     77.000000    1.000000    4.000000  200.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.663366    4.722772
# ...

# %% [markdown]
# age
#
#
# *   Age range:The age in dataset range from 29 to 77 years
# *   Most common age:The most frequently occuring age is 58 years with 19 occurrences

# %% [markdown]
# sex
#
#
# *   The dataset contains a total of 303 individuals of which 206 males(represented by 1) and 97 females (represented by 0)

# %% [markdown]
# cp(chest pain)
#
# *   cp represent different type of chest pain experienced by individuals
# *  1:Typical Angina(chest pain due to decreased blood flow to the heart muscle)
#
#
# *   2:Atypical Angina(chest pain with atypical symptoms)
# *   3:Non Anginal pain(chest pain not related to heart issues)
#
#
# *  4:Asymptomatic(no chest pain experienced)
# *   144 individuals reported asymptomatic
#
#
# *   Non Anginal pain is the second most reported type with 86 individuals
# *   50 individuals reported atypical angina
#
#
# *   23 individual reported typical angina with lower frequency

# %% [markdown]
# Trestbps stands for resting blood pressure.It represent the blood pressure of an individual when they are in rest
#
#
# *   The normal resting blood pressure range for adult is typically less than 120/80 mmHg
# *   A resting blood pressure of 120-129 mmHg is considered elevated while 130 mmHg and above may indicate hypertension
#
#
# *  Values above 140 mmHg are often classified as stage 1 hypertension and anything above 180 mmHg is considered hypertensive crisis
# Summary of trestbps value counts
#
#
# *   Most common values
# 120 mmHg:37 individuals
# 130 mmHg:36 individuals
# 140 mmHg:32 individuals

# %% [markdown]
# fbs stands for fasting blood pressure.It measures the blood sugar level after the patient has been fasted for atleast 8 hours
#
#
# *  The value 0 indicates fasting blood sugar is less than or equal to 120 mg/dl(normal)
# *   The value 1 indicates fasting blood sugar is greater than 120 mg/dl(indicating diabetes)
#
#
# *   258 individuals have a fasting blood sugar less than or equal to 120 mg/dl
# *   45 individuals have a fasting blood sugar greater than 120 mg/dl

# %% [markdown]
# restecg stands for resting electrocardiographic result.
#
#
# *   The value 0 indicate normal ECG(no significant abnormalities in heart rhythm or function)
# *   The value 1 indicate ST-T wave abnormality(condition where blood flow to the heart is reduced)
#
#
# * The value 2 indicate Left ventricular hypertrophy(indicates that the left chamber of the heart may be enlarged which can be due to high blood pressure)
#
#
# *   151 individuals have a normal ECG result(value 0)
# *   148 individuals have left ventricular hypertrophy(value 2)
#
#
# *   4 individuals have ST-T Wave abnormality

# %% [markdown]
# thalach :maximum heart rate achieved during a stress or physical exertion
#
#
# *   Normal Maximum heart rate=220-age
# *   The most frequent heart rate values are 162 bpm(11),160 bpm(9),and 163bpm(9)

# %% [markdown]
# exang:exercise induced angina
#
#
# *   0 indicates no exercise induced angina(person didnot experience chest pain during exercise)
# *   1 indicates presence of exercise induced angina(person experience chest pain during exercise)
#
#
# *  0 occur 204 times means majority of individuals in dataset didnot experience chest pain during exercise
# *   1 occur 99 times means small portion of individuals did experience chest pain during exercise

# %% [markdown]
# oldpeak shows the level of stress or strain on the heart,with higher number indicating more stress or potential heart problem.
#
#
# *   0.0 occurs 99 times means large portion of people didnot experience any ST Depression
# *   1.2 occurs 17 times means a slight ST Depression
#
# *   0.6 and 1.0:Each occur 14 times representing small ST Depression
#
# *   Higher values indicate more severe ST depression

# %% [markdown]
# Slope measures how well the heart  works during exercise
#
#
# *   1 means the heart is healthy and works better under stress
# *   2 means heart's activity remained stable or unchanged during exercise
#
#
# *   3 means heart's activity decreased under stress
#
#
# *   High count for 1 and 2:most people in this dataset have healthy or stable response to exercise

# %% [markdown]
# Ca:how many blockages are in the heart blood vessels
#
#
# *   0 means no blockages
# *   1 means 1 blockage
#
#
# *   2 means 2 blockages
# *   3 means 3 blockages
#
#
# *   ? means there is missing information
# *  High count for 0 (176)
#
#
# *   Low count for 3(20)
# *   Very low count for ?(4)

# %% [markdown]
# thal:refers to thalassemia which is a blood disorder affecting the production of hemoglobin in red blood cells
#
#
# *   3:it indicates healthy heart and good blood circulation
# *   7:fixed defect in blood flow
#
#
# *   6:reversible defects.it means blood flow can be improved with treatment
# *   ?:represent missing or unknown information
#
#
# *   High count for 3(166)
# *   Low count for 6(18)
#
#
# *  Very low count for ?(2)

# %% [markdown]
# num:how many people have heart disease and how serious it is
#
#
# *   0 means there is no heart disease present
# *   1 means presence of some heart disease
#
#
# *   2 means mild heart disease
# *   3 means moderate heart disease
#
#
# *   4 means severe heart disease
# *   high count is for 0
#
#
# *   Low count is for 4

# %% [markdown]
# chol:cholestrol level in the blood
#
# *   Normal cholestrol level:total cholestrol level less than 200mg/dl is considered healthy
# *   Borderline High:cholestrol level between 200mg/dl and 239 mg/dl are considered borderline high
#
#
# *   High cholestrol:levels 240 mg/dl and above are high which increases risk of heart disease
# *   The frequency distribution of chol shows that the most frequent occuring cholestrol levels are around 204mg/dl,197mg/dl,and 234 mg/dl each appearing 6 times

# %% [markdown]
# EDA visualization

# %%
#verify
cd.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# chol        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd.hist(bins=20,figsize=(15,10),color='red')
plt.suptitle('Histogram of Numerical Features',fontsize=16)
plt.show()

# %%
#outlier plot for all columns in data cd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.boxplot(data=cd)
plt.title('Boxplot of Outliers')
plt.show()

# %%
cd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'fbs', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'num', 'chol'],
#       dtype='object')

# %%
#Outliers

# %%
cd.describe()
# Out:
#               age         sex          cp    trestbps         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769    0.148515    0.990099
# std      9.038662    0.467299    0.960126   17.599748    0.356198    0.994971
# min     29.000000    0.000000    1.000000   94.000000    0.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000    0.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000    0.000000    1.000000
# 75%     61.000000    1.000000    4.000000  140.000000    0.000000    2.000000
# max     77.000000    1.000000    4.000000  200.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.663366    4.722772
# ...

# %%
#visualizing outliers using Boxplot
plt.figure(figsize=(10,6))
sns.boxplot(data=cd[['chol','trestbps','thalach','oldpeak']])
plt.title('Boxplot of Outliers')
plt.show()

# %%
import numpy as np
def cal_zscore(data,column):
  return np.abs((data[column]-data[column].mean())/data[column].std())

# %% [markdown]
# outlier flagging using zscore:medical outlier could indicate important clinical cases.instead of removing them flag them so we can track their presence in later stage of analysis

# %%
#Log Transformation
cd['chol_log']=np.log(cd['chol'])
cd['trestbps_log']=np.log(cd['trestbps'])

# %% [markdown]
# Log Tranformation is applied to reduce impact of high values

# %%
cd.to_csv('chol.csv',index=False)

# %%
#scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
numerical_features=cd.select_dtypes(include=['int64','float64']).columns
chda=cd.copy()
chda[numerical_features]=scaler.fit_transform(cd[numerical_features])

# %% [markdown]
# scale to standardize them (mean 0,std 1)

# %%
chda.head()
# Out:
#         age       sex        cp  trestbps       fbs   restecg   thalach  \
# 0  0.948726  0.686202 -2.251775  0.757525  2.394438  1.016684  0.017197
# 1  1.392002  0.686202  0.877985  1.611220 -0.417635  1.016684 -1.821905
# 2  1.392002  0.686202  0.877985 -0.665300 -0.417635  1.016684 -0.902354
# 3 -1.932564  0.686202 -0.165268 -0.096170 -0.417635 -0.996749  1.637359
# 4 -1.489288 -1.457296 -1.208521 -0.096170 -0.417635  1.016684  0.980537
#
#       exang   oldpeak     slope        ca      thal       num      chol  \
# 0 -0.696631  1.087338  2.274579 -0.711131  0.660004 -0.764198 -0.264900
# 1  1.435481  0.397182  0.649113  2.504881 -0.890238  0.866450  0.760415
# 2  1.435481  1.346147  0.649113  1.432877  1.176752  0.051126 -0.342283
# 3 -0.696631  2.122573  2.274579 -0.711131 -0.890238 -0.764198  0.063974
# 4 -0.696631  0.310912 -0.976352 -0.711131 -0.890238 -0.764198 -0.825922
#
#    chol_log  trestbps_log
# 0 -0.178793      0.804388
# 1  0.830453      1.559304
# ...

# %%
chda.to_csv('chol.csv',index=False)

# %%
#define target variable and features
x=chda.drop('chol',axis=1)
y=chda['chol']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb

# Define the model
xgb_model = xgb.XGBRegressor(random_state=42)

# Extend the parameter grid for Randomized Search
param_grid = {
    'n_estimators': [300, 400, 500],         # Increase number of trees
    'learning_rate': [0.01, 0.05],           # Lower learning rate
    'max_depth': [3, 4, 5, 6],               # Deeper trees
    'subsample': [0.7, 0.8, 0.9, 1.0],       # More robust sampling
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],# More features sampled
    'reg_alpha': [0, 0.1, 1],                # L1 regularization
    'reg_lambda': [0, 0.1, 1]                # L2 regularization
}

# Create the randomized search object with more iterations
random_search = RandomizedSearchCV(estimator=xgb_model,
                                   param_distributions=param_grid,
                                   n_iter=20,                # Increase the random combinations
                                   scoring='neg_mean_squared_error',
                                   cv=5,                     # 5-fold cross-validation
                                   verbose=1,
                                   n_jobs=-1,                # Use all available cores
                                   random_state=42)

# Fit the randomized search to the data
random_search.fit(x_train, y_train) # This line was missing, causing the error

# Best parameters found
print(f"Best parameters: {random_search.best_params_}")

# Best model
best_xgb_model = random_search.best_estimator_

# Make predictions on the test set
y_pred_best_xgb = best_xgb_model.predict(x_test)

# Evaluate the model's performance
mse_best_xgb = mean_squared_error(y_test, y_pred_best_xgb)
r2_best_xgb = r2_score(y_test, y_pred_best_xgb)

print(f"Best XGBoost Mean Squared Error: {mse_best_xgb}")
print(f"Best XGBoost R-squared: {r2_best_xgb}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best parameters: {'subsample': 0.9, 'reg_lambda': 0.1, 'reg_alpha': 0, 'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.05, 'colsample_bytree': 1.0}
# Best XGBoost Mean Squared Error: 0.13572979868632973
# Best XGBoost R-squared: 0.9103853612899744

# %%
#pickle model
import pickle
pickle.dump(best_xgb_model,open('xgbnew.pkl','wb'))

# %%
pip install shap

# %%
import shap
import matplotlib.pyplot as plt

# Initialize the SHAP explainer for your trained XGBoost model
explainer = shap.Explainer(best_xgb_model, x_train)

# Calculate SHAP values for the training data
shap_values = explainer(x_train)

# Global feature importance (summary plot)
shap.summary_plot(shap_values, x_train)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import shap
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('/content/newchol.csv')

# Check for missing values
print(df.isnull().sum())
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0         0.0     0.0                0
# 1     0   46              0         0.0     0.0                0
# 2     1   48              1        20.0     0.0                0
# 3     0   61              1        30.0     0.0                0
# 4     0   46              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
# Creating new interaction features

# Creating new interaction features

df['c_Age'] = df['totChol'] * df['age']

# Polynomial Features (2nd degree for now)
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(df[['age', 'BMI', 'sysBP', 'diaBP']])
poly_feature_names = poly.get_feature_names_out(['age', 'BMI', 'sysBP', 'diaBP'])

# Convert the polynomial features into a DataFrame
poly_df = pd.DataFrame(poly_features, columns=poly_feature_names)

# Add these polynomial features to the original DataFrame
df = pd.concat([df, poly_df], axis=1)

# %%
#dfdrop duplicate
df = df.drop_duplicates()

# %%
df.drop(['TenYearCHD'],inplace=True,axis=1)

# %%
# Define target and features
X = df.drop(columns=['totChol'])  # Exclude the target column
Y = df['totChol']  # Cholesterol level as target

# Split the data into training and test sets
X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))  # Adjust figure size for better visibility
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8}) # Reduced font size
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# prompt: select features which are highly correlated with totChol

# Calculate the correlation of all features with 'totChol'
correlation_with_totChol = df.corr()['totChol'].abs().sort_values(ascending=False)

# Set a threshold for high correlation (e.g., 0.3)
threshold = 0.3

# Select features with correlation above the threshold
highly_correlated_features = correlation_with_totChol[correlation_with_totChol > threshold]

print("Features highly correlated with totChol:")
highly_correlated_features
# Out:
# Features highly correlated with totChol:
# totChol    1.00000
# c_Age      0.81157
# Name: totChol, dtype: float64

# %%
# Initialize the model
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf.fit(X_train_scaled, Y_train)

# Make predictions
Y_pred_train = rf.predict(X_train_scaled)
Y_pred_test = rf.predict(X_test_scaled)

# Evaluate the model
train_mse = mean_squared_error(Y_train,Y_pred_train)
test_mse = mean_squared_error(Y_test, Y_pred_test)
train_r2 = r2_score(Y_train, Y_pred_train)
test_r2 = r2_score(Y_test, Y_pred_test)

print(f'Train MSE: {train_mse}, Train R2: {train_r2}')
print(f'Test MSE: {test_mse}, Test R2: {test_r2}')
# Out:
# Train MSE: 3.1827520341981157, Train R2: 0.998334958670155
# Test MSE: 58.06492016509435, Test R2: 0.9741987538344138

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(20, 18))  # Adjusting the figure size for better visibility

# Draw the heatmap with annotations
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True,
            cbar_kws={"shrink": .8}, linewidths=.5, annot_kws={"size": 12})  # Increase annot_kws for better visibility

# Set title and axis labels
plt.title('Correlation Matrix', fontsize=30)  # Adjusting title font size
plt.xticks(fontsize=16)  # Adjusting x-axis labels font size
plt.yticks(fontsize=16)  # Adjusting y-axis labels font size
plt.tight_layout()  # Adjust layout to avoid overlap

plt.show()

# %%
import shap
import matplotlib.pyplot as plt

# Initialize the SHAP explainer for your trained XGBoost model
explainer = shap.Explainer(rf, X_train)

# Calculate SHAP values for the training data
shap_values = explainer(X_train)

# Global feature importance (summary plot)
shap.summary_plot(shap_values, X_train)
# Out:
#  98%|===================| 3341/3392 [00:12<00:00]

# %%
# Combine predictions from both models
predictions1 = best_xgb_model.predict(x_test)
predictions2 = model.predict(X_test)

# Average the predictions for a final prediction
final_predictions = (predictions1 + predictions2) / 2

# Add predictions to the original data for analysis
data['Prediction_Model1'] = predictions1
data['Prediction_Model2'] = predictions2
data['Final_Prediction'] = final_predictions

# Optionally evaluate the final predictions
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y, final_predictions)
r2 = r2_score(y, final_predictions)

print("Final Predictions:")
print(data[['Final_Prediction', 'Prediction_Model1', 'Prediction_Model2']].head())
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-914fb309af0d> in <cell line: 3>()
#       1 # Combine predictions from both models
#       2 predictions1 = best_xgb_model.predict(x_test)
# ----> 3 predictions2 = model.predict(X_test)
#       4
#       5 # Average the predictions for a final prediction
#
# NameError: name 'model' is not defined

# %%
# Combine the datasets for training/testing
x1 = pd.concat([x, X], ignore_index=True)
y1 = pd.concat([y, Y], ignore_index=True)

# Split the combined data for stacking
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.2, random_state=42)

# Predict using both models on the test set
predictions1 = best_xgb_model.predict(x_test)
predictions2 = model.predict(X_test)

# Create a new DataFrame for the meta-model
meta_X = pd.DataFrame({
    'Prediction_Model1': predictions1,
    'Prediction_Model2': predictions2
})

# Train a meta-model (e.g., Linear Regression)
meta_model = LinearRegression()
meta_model.fit(meta_X, y_test)

# Make final predictions using the meta-model
final_predictions = meta_model.predict(meta_X)

# Evaluate the final predictions
mse = mean_squared_error(y_test, final_predictions)
r2 = r2_score(y_test, final_predictions)

print("Final Predictions:")
print(final_predictions[:5])  # Display the first five predictions
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# %%
# Combine the datasets for training/testing
x1 = pd.concat([x, X], ignore_index=True)
y1 = pd.concat([y, Y], ignore_index=True)

# Check the shapes of x1 and y1
print(f"Shape of x1: {x1.shape}")
print(f"Shape of y1: {y1.shape}")

# Ensure y1 has the same number of rows as x1
# Assuming y1 has more rows, select only the first 'x1.shape[0]' rows
y1 = y1[:x1.shape[0]]

# Split the combined data for stacking
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.2, random_state=42)

# ... (Rest of your code)

# %%
# Get the feature names used during training
training_features = model.feature_names_in_

# Ensure X_test and x_test have the same features in the same order and same number of samples
# Assuming x_test has fewer features or samples, you might need to adjust this:
# 1. Add missing features to x_test with fillna(0) or a suitable strategy.
# 2. Select a subset of X_test with the same number of samples as x_test.

# Here's an example assuming you need to align x_test with X_test:
x_test = x_test[[col for col in training_features if col in x_test.columns]] # Select common columns
x_test = x_test.fillna(0) # Fill missing values with 0 (adjust if needed)
x_test = x_test.iloc[:min(x_test.shape[0], X_test.shape[0])] # Select a subset of rows if needed
X_test = X_test[training_features].iloc[:min(x_test.shape[0], X_test.shape[0])]  # Select subset of rows and align features

# Predict using both models on the test set (using aligned data)
predictions1 = best_xgb_model.predict(x_test)
predictions2 = model.predict(X_test)

# ... (rest of your code)

# Create a new DataFrame for the meta-model
meta_X = pd.DataFrame({
    'Prediction_Model1': predictions1,
    'Prediction_Model2': predictions2
})

# ... (rest of your code)

# Train a meta-model (e.g., Linear Regression)
meta_model = LinearRegression()
meta_model.fit(meta_X, y_test)

# Make final predictions using the meta-model
final_predictions = meta_model.predict(meta_X)

# Evaluate the final predictions
mse = mean_squared_error(y_test, final_predictions)
r2 = r2_score(y_test, final_predictions)

print("Final Predictions:")
print(final_predictions[:5])  # Display the first five predictions
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# %%
# Fit and predict for chol target
xgb_model = xgb.XGBRegressor(random_state=42)  # Or your preferred model
model_chol.fit(X_train, y_train)  # Assuming you have X_train_chol, y_train_chol
y_pred_chol = model_chol.predict(X_test)  # Assuming you have X_test_chol

# Fit and predict for fram target (similarly)
model_fram = RandomForestRegressor(random_state=42)
model_fram.fit(X_train, y_train)
y_pred_fram = model_fram.predict(X_test)

# Combine predictions for Bagging
combined_X_test = pd.DataFrame({
    'chol_pred': y_pred_chol,
    'fram_pred': y_pred_fram
})

# Instead of concatenating y_test with itself, just use y_test
y_combined = y_test.values

# Train a Bagging Regressor on combined predictions
from sklearn.ensemble import BaggingRegressor
# Replace 'base_estimator' with 'estimator'
bagging_model = BaggingRegressor(estimator=RandomForestRegressor(random_state=42), n_estimators=10, random_state=42)
bagging_model.fit(combined_X_test, y_combined)

# Make predictions with the Bagging model
y_pred_bagging = bagging_model.predict(combined_X_test)

# Evaluate the Bagging model
bagging_mse = mean_squared_error(y_combined, y_pred_bagging)
bagging_r2 = r2_score(y_combined, y_pred_bagging)
bagging_mae = mean_absolute_error(y_combined, y_pred_bagging)

print("Bagging Random Forest Model Evaluation:")
print(f"Mean Squared Error: {bagging_mse}")
print(f"R-squared: {bagging_r2}")
print(f"Mean Absolute Error: {bagging_mae}")
